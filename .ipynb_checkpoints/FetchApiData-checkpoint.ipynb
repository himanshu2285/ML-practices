# %%
import pandas as pd
import requests

# %%
reseponse = requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=043a987b32d2232e70735e7242a15f75&language=en-US&page=1")

# %%
movie_df = pd.DataFrame(response.json()['results'])[['id','original_title','overview','title','vote_count']]
movie_df
# Out:
#         id                                 original_title  \
# 0      278                       The Shawshank Redemption
# 1      238                                  The Godfather
# 2      240                          The Godfather Part II
# 3      424                               Schindler's List
# 4      389                                   12 Angry Men
# 5      129                                       千と千尋の神隠し
# 6      155                                The Dark Knight
# 7    19404                   दिलवाले दुल्हनिया ले जायेंगे
# 8      497                                 The Green Mile
# 9   496243                                            기생충
# 10     122  The Lord of the Rings: The Return of the King
# 11     680                                   Pulp Fiction
# 12  372058                                          君の名は。
# 13      13                                   Forrest Gump
# 14  157336                                   Interstellar
# ...
