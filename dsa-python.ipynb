# %%
##### Dictionary #####

dic = {'age':20}
# dic.get('sal', 0)
# for k, val in dic.items():
#     print(k, val)
# dic.keys()
# dic.values()
# dic.clear()
# new = dic.copy()
# new['age']=40
# new
# dic
# pop_dic = dic.popitem()
# # dic
# pop_dic
# dic.setdefault('name', 'pqr')

dic.update({'sal':2000, 'age':40})
dic.update([('age',40), ('sal', 40000)]) # by using iterable tuple
dic

# dic -> items(), pop(), popitem(), clear(), copy(), get(), keys(), values(), setdefault(), update()

# %%
##### List #####
# names = ['apple', 'google', 'yahoo', 'amazon', 'facebook', 'instagram', 'microsoft'] 
# names[::2]
# print(dir(dict))
nums = [1,2,3,4,5]
# nums.append(3)
# nums.append(4)
# nums.append([3,4])
# len(nums)
# nums.extend([3,4,5,6,7])
# len(nums)
# nums.pop(2)
nums

# %% [markdown]
# #### prime number

# %%
def prime_number(num):
    if num<=1:
        return False
    else:
        for i in range(2, int(num**0.5)+1):
            if num%i==0:
                return False
        return True
    
n = eval(input('Enter a number :'))
prime = prime_number(n)
if prime:
    print(n,'is a prime number')
else:
    print(n,'is not a prime number')
# Out:
# 11 is a prime number

# %% [markdown]
# #### Factorial

# %%
def fact(n: int):
    if n==0 or n==1:
        return 1
    else:
        f=1
        for i in range(1, n+1):
            f*=i
        return f

num = eval(input('Enter a number'))
print(fact(num))
# Out:
# 1

# %% [markdown]
# #### Sum of prime number

# %%
nums = [2,12,13,14,37,59]
def prime_number(num):
    if num<=1:
        return False
    else:
        for i in range(2, int(num**0.5)+1):
            if num%i==0:
                return False
        return True

total=0
for num in nums:
    if prime_number(num):
        total+=num
    else:
        continue
print(total)
# Out:
# 111

# %% [markdown]
# #### Fibonacci Series

# %%
def fiboncci(num: int):
    n1,n2=0,1
    print(f'series : {n1} {n2}', end=' ')
    for i in range(0, num):
        res=n1+n2
        print(res, end=' ')
        n1,n2=n2,res
n=int(input('Enter a number to create fibonacci series :'))
fiboncci(n)
# Out:
# series : 0 1 1 2 3 5 8 13 21

# %% [markdown]
# #### Rerverse Number

# %%
def reverse_num(num):
    num=abs(num)
    rev=0
    while(num>0):
        rem=num%10
        rev=rev*10+rem
        num=num//10
    return rev

try:
    num=int(input(''))
    if num < 0:
        print('-' + str(reverse_num(num)))
    else:
        print(reverse_num(num))
except ValueError:
    print('Given input is not valid')
else:      # it executes when the try block run properly
    print('Our code run properly without any error')
finally:
    print('This block always excute, even if the error occur then also')
# Out:
# Given input is not valid
# This block always excute, even if the error occur then also

# %% [markdown]
# #### Reverse a string

# %%
name = 'Nikita'
name[::-1]

rev=''
for ele in name:
    rev=ele+rev
rev
# Out:
# 'atikiN'

# %% [markdown]
# #### String Questions
# Extrct lowercase chars if their ascii values are even.

# %%
name='Steve jobs'
for ch in name:
    if ord(ch)%2==0 and 'a'<=ch<='z':
        print(ch, end='')
# Out:
# tvjb

# %% [markdown]
# WAP to extract all the key value pairs from the dictionary only if the keys are of string datatype and values are integers

# %%
# 1st way - isinstance
dic={"Name":"XYZ", "Age":20, "Sal":40000, "Loc":"Mumbai"}
res={}
for i in dic:
    if isinstance(i, str) and isinstance(dic[i], int):
        res[i]=dic[i]
res
# Out:
# {'Age': 20, 'Sal': 40000}

# %%
# 2nd way - checking type of data
res1={}
for key, val in dic.items():
    if type(key)==str and type(val)==int:
        res1[key]=val
res1
# Out:
# {'Age': 20, 'Sal': 40000}

# %% [markdown]
# Get the following output
# <br>s='power star'
# <br>out={'power':5, 'star':4}

# %%
s='power star'
res={}
for ch in s.split():
    res[ch]=len(ch)
res
# Out:
# {'power': 5, 'star': 4}

# %%
# without using len function
res1={}
words = s.split()
for i in words:
    count=0
    for j in i:
        count+=1
    res1[i]=count
res1
# Out:
# {'power': 5, 'star': 4}

# %% [markdown]
# print vowels from string

# %%
s='Rushikesh'
for ch in s:
    if ch in 'aeiouAEIOU':
        print(ch, end='')
# Out:
# uie

# %% [markdown]
# print all integers from List

# %%
lst = [1,2,'Tom',23.4,'jack',5,2+5j]
res=[]
for ele in lst:
    if type(ele)==int:
        res.append(ele)
res
# Out:
# [1, 2, 5]

# %% [markdown]
# Remove duplicate value from List

# %%
# 1st way
lst = [1,3,5,6,3,5,8,9,10,45,34,8,23,'a','b','s','a']
print(list(set(lst)))

# 2nd way
res=[]
for ele in lst:
    if ele not in res:
        res.append(ele)
res
# Out:
# [1, 34, 3, 5, 6, 8, 9, 10, 45, 'a', 23, 's', 'b']
# [1, 3, 5, 6, 8, 9, 10, 45, 34, 23, 'a', 'b', 's']

# %% [markdown]
# Now just print total vowel
# out = {'power':2, 'star':1}

# %%
s='power star' 
res={}
for ch in s.split():
    count=0
    for j in ch:
        if j in 'aeiouAEIOU':
            count+=1
    res[ch]=count
res
# Out:
# {'power': 2, 'star': 1}

# %% [markdown]
# Get the following output
# IN = 'bacbcaabbaa'
# out = 'b4a5c2'

# %%
Ip = 'bacbcaabbaa'
res=''
for i in Ip:
    count=0
    for j in Ip:
        if i==j:
            count+=1
    if i not in res:
        res+=i+str(count)
res
# Out:
# 'b4a5c2'

# %% [markdown]
# <br>Get Following Output
# <br>IN = {10:'star', 20:'Bye', 30:'moon', 40:'apple'}
# <br>out={10:'a', 20:'e', 30:'oo', 40:'ae'}

# %%
IN = {10:'star', 20:'Bye', 30:'moon', 40:'apple'}
out={}
for key in IN:
    vowels=''
    for ele in IN[key]:
        if ele in 'aeiouAEIOU':
            vowels+=ele
    out[key]=vowels
out
# Out:
# {10: 'a', 20: 'e', 30: 'oo', 40: 'ae'}

# %% [markdown]
# Count the occurances of characters

# %%
name='Chris bumsted'
name=name.replace(' ', '') # removing whitespace
count={}
for ch in name.lower():
    if ch in count:
        count[ch]+=1
    else:
        count[ch]=1
print(count)
# Out:
# {'c': 1, 'h': 1, 'r': 1, 'i': 1, 's': 2, 'b': 1, 'u': 1, 'm': 1, 't': 1, 'e': 1, 'd': 1}

# %% [markdown]
# Extract string from list which are palindrome

# %%
lst=[10,20,'yash','aba','nitin']
res=[]
for ele in lst:
    if type(ele)==str and ele==ele[::-1]:
        res.append(ele) 
res
# Out:
# ['aba', 'nitin']

# %% [markdown]
# check whether list is homogeneous or not

# %%
l=['s',2,3,5]
first_char=l[0]
for ele in range(1, len(l)):
    if type(l[ele])==type(first_char):
        continue
    else:
        print('not homogenous')
        break
# Out:
# not homogenous
