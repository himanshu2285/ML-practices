# %% [markdown]
# # Pandas practice with some code

# %% [markdown]
# ## Creating, Reading and Writing

# %% [markdown]
# ![image.png](attachment:88e2ebd8-74a2-4be6-b213-1ed168a5b8eb.png)

# %%
# Your code goes here. Create a dataframe matching the above diagram and assign it to the variable fruits.
import pandas as pd
import numpy as np
fruits = np.array([[30,21,25],[45,67,89]])

fruits_df = pd.DataFrame(fruits)
fruits_df.columns = ["Apples","Bananas","Cherry"]
fruits_df.index=["r1","r2"]

# Check your answer
fruits_df
# Out:
#     Apples  Bananas  Cherry
# r1      30       21      25
# r2      45       67      89

# %% [markdown]
# ![image.png](attachment:6adc4aaa-6c04-4f21-9d5a-a833098d03fe.png)

# %% [markdown]
# #### Know how to add Column names and row names(index)

# %%
# Your code goes here. Create a dataframe matching the above diagram and assign it to the variable fruit_sales.
import numpy as np
import pandas as pd
fruit_sales = np.array([[35,21],[41,34]])
fruit_sales_df = pd.DataFrame(fruit_sales)
fruit_sales_df.columns = ["Apples","Bananas"]
fruit_sales_df.index = ["2017 Sales","2018 Sales"]

# Check your answer
fruit_sales_df
# q2.check()
# fruit_sales
# Out:
#             Apples  Bananas
# 2017 Sales      35       21
# 2018 Sales      41       34

# %% [markdown]
# ![image.png](attachment:08cf8e38-8651-4625-aae0-37bb007b8410.png)
# #### Use name= parameter to give name of Series

# %%
import numpy as np
import pandas as pd

ingredients = pd.Series([["Flour","4 cups"],["Milk","1 cup"],["Eggs","2 large"],["Spam", "1 can"]], name="Dinner")
ingredients
# Out:
# 0    [Flour, 4 cups]
# 1      [Milk, 1 cup]
# 2    [Eggs, 2 large]
# 3      [Spam, 1 can]
# Name: Dinner, dtype: object

# %% [markdown]
# #### 4. Read the following csv dataset of wine reviews into a DataFrame called reviews:

# %% [markdown]
# ![image.png](attachment:fce6815d-6032-4fdd-9e4b-673e2ce2a29a.png)
# #### Use index_col=0 to avoid unmatched column name error

# %%
import numpy as np
import pandas as pd
reviews = pd.read_csv("datasets/csv/winemag-data_first150k.csv", index_col=0)

# Check your answer
reviews
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 4       France  This is the top wine from La Bégude, named aft...
# ...        ...                                                ...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# 0                          Martha's Vineyard      96  235.0
# ...

# %% [markdown]
# #### Creating Dog and goat DataFrame

# %%
animals = pd.DataFrame({"Cows":[12,20], "Goats":[22,19]}, index = ["year 1", "year 2"])
animals
# Out:
#         Cows  Goats
# year 1    12     22
# year 2    20     19

# %% [markdown]
# In the cell below, write code to save this DataFrame to disk as a csv file with the name cows_and_goats.csv.

# %%
animals.to_csv("cow_and_gots.csv")

# %% [markdown]
# ## Indexing, Selecting & Assigning

# %% [markdown]
# 1. df.iloc[] : Index-based selection: selecting data based on its numerical position in the data. iloc follows this paradigm.
# 2. df.loc[] : Label-based selection. In this paradigm, it's the data index value, not its position, which matters.

# %% [markdown]
# df.iloc[row, column] <br> 1. reviews.iloc[0] for accessing the first row <br> 2. reviews.iloc[:, 0] for all row & first column <br> 3. reviews.iloc[:3, 0] starting 3 rows and first column <br> 4. reviews.iloc[1:3, 0] Starting 2 rows and first column <br> 5. reviews.iloc[[0, 1, 2], 0] we can also pass a list <br> 6. reviews.iloc[-5:] from last 5 values to start <br

# %% [markdown]
# loc[row, column] <br> 1. reviews.loc[0, 'country'] first row and country column <br> 2. reviews.loc[:, ['taster_name', 'taster_twitter_handle', 'points']]

# %% [markdown]
# when the DataFrame index is a simple numerical list, e.g. 0,...,1000. In this case df.iloc[0:1000] will return 1000 entries, while df.loc[0:1000] return 1001 of them! To get 1000 elements using loc, you will need to go one lower and ask for df.loc[0:999].

# %% [markdown]
# ### Manipulating the index

# %% [markdown]
# reviews.set_index("title")

# %% [markdown]
# ![image.png](attachment:b204b3ea-5b5b-4994-8ec9-33a817a53cfa.png)

# %% [markdown]
# #### Conditional selection
# reviews.country == 'Italy'  => This will only return True or False values <br>
# reviews.loc[reviews.country == 'Italy'] => It will return the values based on the condition <br>
# reviews.loc[(reviews.country == 'Italy') & (reviews.points >= 90)]

# %% [markdown]
# reviews.loc[(reviews.country == 'Italy') | (reviews.points >= 90)] => Suppose we'll buy any wine that's made in Italy or which is rated above average. For this we use a pipe (|): <br>
# reviews.loc[reviews.country.isin(['Italy', 'France'])] => select data whose values is in list of values. <br>
# reviews.loc[reviews.price.notnull()]

# %% [markdown]
# ### Assigning data

# %% [markdown]
# reviews['critic'] = 'everyone' <br>
# reviews['critic']

# %% [markdown]
# reviews['index_backwards'] = range(len(reviews), 0, -1) <br>
# reviews['index_backwards']

# %% [markdown]
# ![image.png](attachment:826b6eb7-da37-4f15-89f2-b4cbb3b3178f.png)

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# 1. Select the description column from reviews and assign the result to the variable desc.

# %%
reviews = pd.read_csv("datasets/csv/winemag-data_first150k.csv", index_col=0)
reviews.head()
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# ...

# %%
reviews = pd.read_csv("datasets/csv/winemag-data_first150k.csv", index_col=0)
desc = reviews['description']
desc.head()
# Out:
# 0    This tremendous 100% varietal wine hails from ...
# 1    Ripe aromas of fig, blackberry and cassis are ...
# 2    Mac Watson honors the memory of a wine once ma...
# 3    This spent 20 months in 30% new French oak, an...
# 4    This is the top wine from La Bégude, named aft...
# Name: description, dtype: object

# %% [markdown]
# 2. Select the first value from the description column of reviews, assigning it to variable first_description.

# %%
first_description = reviews["description"][0]
first_description
# Out:
# 'This tremendous 100% varietal wine hails from Oakville and was aged over three years in oak. Juicy red-cherry fruit and a compelling hint of caramel greet the palate, framed by elegant, fine tannins and a subtle minty tone in the background. Balanced and rewarding from start to finish, it has years ahead of it to develop further nuance. Enjoy 2022–2030.'

# %% [markdown]
# 3. Select the first row of data (the first record) from reviews, assigning it to the variable first_row.

# %%
first_row = reviews.head(1)
first_row
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
#
#          designation  points  price    province     region_1 region_2  \
# 0  Martha's Vineyard      96  235.0  California  Napa Valley     Napa
#
#               variety winery
# 0  Cabernet Sauvignon  Heitz

# %% [markdown]
# 4. Select the first 10 values from the description column in reviews, assigning the result to variable first_descriptions.
#
# Hint: format your output as a pandas Series.

# %%
first_descriptions_10 = reviews["description"]
df = first_descriptions_10.head(10)

first_description = pd.Series(df)
first_description
# Out:
# 0    This tremendous 100% varietal wine hails from ...
# 1    Ripe aromas of fig, blackberry and cassis are ...
# 2    Mac Watson honors the memory of a wine once ma...
# 3    This spent 20 months in 30% new French oak, an...
# 4    This is the top wine from La Bégude, named aft...
# 5    Deep, dense and pure from the opening bell, th...
# 6    Slightly gritty black-fruit aromas include a s...
# 7    Lush cedary black-fruit aromas are luxe and of...
# 8    This re-named vineyard was formerly bottled as...
# 9    The producer sources from two blocks of the vi...
# Name: description, dtype: object

# %% [markdown]
# 5. Select the records with index labels 1, 2, 3, 5, and 8, assigning the result to the variable sample_reviews.
#
# In other words, generate the following DataFrame:

# %%
sample_reviews = reviews.loc[[1,2,3,5,8]]
sample_reviews
# Out:
#   country                                        description  \
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 5   Spain  Deep, dense and pure from the opening bell, th...
# 8      US  This re-named vineyard was formerly bottled as...
#
#                             designation  points  price        province  \
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 5                             Numanthia      95   73.0  Northern Spain
# 8                                Silice      95   65.0          Oregon
#
#              region_1           region_2          variety  \
# 1                Toro                NaN    Tinta de Toro
# ...

# %% [markdown]
# 6. Create a variable df containing the country, province, region_1, and region_2 columns of the records with the index labels 0, 1, 10, and 100. In other words, generate the following DataFrame:

# %% [markdown]
# ![image.png](attachment:39869178-431b-4b24-a1cf-29c87ae1c236.png)

# %%
import numpy as np
df = pd.DataFrame({"country":["Italy","Portugal","US","US"], "province":["Sicily & Sardinia","Douro","California","New York"], "region_1":["Etna",np.nan,"Napa Valley","Finger Lakes"], "region_2":[np.nan,np.nan,"Napa","Finger Lakes"]}, 
                  index=[0,1,10,100])

# Check your answer
df
# Out:
#       country           province      region_1      region_2
# 0       Italy  Sicily & Sardinia          Etna           NaN
# 1    Portugal              Douro           NaN           NaN
# 10         US         California   Napa Valley          Napa
# 100        US           New York  Finger Lakes  Finger Lakes

# %% [markdown]
# 7. Create a variable df containing the country and variety columns of the first 100 records.

# %% [markdown]
# ![image.png](attachment:0a4d3a51-31cc-45cd-aacb-06e2851d2846.png)

# %%
# First Way
df_new = reviews[["country","variety"]]
df = df_new.head(100)
# Check your answer
df
# Out:
#    country               variety
# 0       US    Cabernet Sauvignon
# 1    Spain         Tinta de Toro
# 2       US       Sauvignon Blanc
# 3       US            Pinot Noir
# 4   France    Provence red blend
# ..     ...                   ...
# 95  France         Malbec-Merlot
# 96      US            Chardonnay
# 97      US    Cabernet Sauvignon
# 98  France         Merlot-Malbec
# 99  France  Ugni Blanc-Colombard
#
# [100 rows x 2 columns]

# %%
# Second Way
cols = ["country","variety"]
df = reviews.loc[:99, cols]
df

# cols_idx = [0, 11]
# df = reviews.iloc[:100, cols_idx]
# df
# Out:
#    country               variety
# 0       US    Cabernet Sauvignon
# 1    Spain         Tinta de Toro
# 2       US       Sauvignon Blanc
# 3       US            Pinot Noir
# 4   France    Provence red blend
# ..     ...                   ...
# 95  France         Malbec-Merlot
# 96      US            Chardonnay
# 97      US    Cabernet Sauvignon
# 98  France         Merlot-Malbec
# 99  France  Ugni Blanc-Colombard
#
# [100 rows x 2 columns]

# %% [markdown]
# 8. Create a DataFrame italian_wines containing reviews of wines made in Italy. Hint: reviews.country equals what?

# %%
italian_wines = reviews[reviews["country"] == "Italy"]

# Check your answer
italian_wines
# Out:
#        country                                        description  \
# 10       Italy  Elegance, complexity and structure come togeth...
# 32       Italy  Underbrush, scorched earth, menthol and plum s...
# 35       Italy  Forest floor, tilled soil, mature berry and a ...
# 37       Italy  Aromas of forest floor, violet, red berry and ...
# 38       Italy  This has a charming nose that boasts rose, vio...
# ...        ...                                                ...
# 150920   Italy  Rich and mature aromas of smoke, earth and her...
# 150922   Italy  Made by 30-ish Roberta Borghese high above Man...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                designation  points  price            province  \
# 10      Ronco della Chiesa      95   80.0  Northeastern Italy
# ...

# %% [markdown]
# 9. Create a DataFrame top_oceania_wines containing all reviews with at least 95 points (out of 100) for wines from Australia or New Zealand.

# %% [markdown]
# ## Summary Functions and Maps

# %%
import pandas as pd 
import numpy as np

# %%
reviews = pd.read_csv("datasets/csv/winemag-data_first150k.csv", index_col = 0)
reviews
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 4       France  This is the top wine from La Bégude, named aft...
# ...        ...                                                ...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# 0                          Martha's Vineyard      96  235.0
# ...

# %% [markdown]
# **Summary functions**:
# Pandas provides many simple "summary functions" (not an official name) which restructure the data in some useful way. For example, consider the describe() method:

# %%
reviews.points.describe()
# Out:
# count    150930.000000
# mean         87.888418
# std           3.222392
# min          80.000000
# 25%          86.000000
# 50%          88.000000
# 75%          90.000000
# max         100.000000
# Name: points, dtype: float64

# %% [markdown]
# This method generates a high-level summary of the attributes of the given column. It is type-aware, meaning that its output changes based on the data type of the input. The output above only makes sense for numerical data; for string data here's what we get:

# %%
reviews.province.describe()
# Out:
# count         150925
# unique           455
# top       California
# freq           44508
# Name: province, dtype: object

# %% [markdown]
# top = Most frequent Value

# %% [markdown]
# If you want to get some particular simple summary statistic about a column in a DataFrame or a Series, there is usually a helpful pandas function that makes it happen.
#
# For example, to see the mean of the points allotted (e.g. how well an averagely rated wine does), we can use the mean() function:

# %%
reviews.points.mean()
# Out:
# np.float64(87.8884184721394)

# %% [markdown]
# To see a list of unique values we can use the **unique()** function:

# %%
reviews.province.unique()
# Out:
# array(['California', 'Northern Spain', 'Oregon', 'Provence',
#        'Northeastern Italy', 'Southwest France', 'Kumeu', 'Washington',
#        'Bulgaria', 'Tuscany', 'France Other', 'Rhône Valley', 'Galicia',
#        'Andalucia', 'Idaho', 'Burgundy', 'Loire Valley', 'New York',
#        'Mendoza Province', 'Victoria', 'Alentejano', 'Piedmont',
#        'Alentejo', 'Champagne', 'Upper Galilee', 'Beira Atlantico',
#        'Veneto', 'Douro', 'Tejo', 'Stellenbosch', 'Levante',
#        'Sicily & Sardinia', 'Southern Italy', 'Languedoc-Roussillon',
#        'Bordeaux', 'Atalanti Valley', 'Catalonia', 'Santorini', 'Florina',
#        'Marchigue', 'Colchagua Valley', 'Curicó Valley', 'Nemea',
#        'Maule Valley', 'Alsace', 'Guerrouane', 'Colinele Dobrogei',
#        'Central Spain', 'Vinho Verde', 'Mosel', 'Rheinhessen',
#        'Golan Heights', 'Württemberg', 'Ahr', 'British Columbia',
#        'Moldova', 'Spain Other', 'Sopron', 'Other', 'Walker Bay', 'Dão',
# ...

# %% [markdown]
# To see a list of unique values and how often they occur in the dataset, we can use the **value_counts()** method:

# %%
reviews.winery.value_counts()
# Out:
# winery
# Williams Selyem          374
# Testarossa               274
# DFJ Vinhos               258
# Chateau Ste. Michelle    225
# Columbia Crest           217
#                         ...
# Black Creek                1
# Heathfield Ridge           1
# Viñalcasta                 1
# Arcs                       1
# Soleira                    1
# Name: count, Length: 14810, dtype: int64

# %% [markdown]
# #### Maps:
# A map is a term, borrowed from mathematics, for a function that takes one set of values and "maps" them to another set of values. In data science we often have a need for creating new representations from existing data, or for transforming data from the format it is in now to the format that we want it to be in later. Maps are what handle this work, making them extremely important for getting your work done!

# %% [markdown]
# There are two mapping methods that you will use often.
# 1. map()

# %%
reviews_point_mean = reviews.points.mean()
reviews.points.map(lambda p: p - reviews_point_mean)
# Out:
# 0         8.111582
# 1         8.111582
# 2         8.111582
# 3         8.111582
# 4         7.111582
#             ...
# 150925    3.111582
# 150926    3.111582
# 150927    3.111582
# 150928    2.111582
# 150929    2.111582
# Name: points, Length: 150930, dtype: float64

# %% [markdown]
# 2. apply() is the equivalent method if we want to transform a whole DataFrame by calling a custom method on each row.

# %%
def remean_points(row):
    row.points = row.points - reviews_point_mean
    return row

reviews.apply(remean_points, axis='columns')
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 4       France  This is the top wine from La Bégude, named aft...
# ...        ...                                                ...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation    points  price  \
# 0                          Martha's Vineyard  8.111582  235.0
# ...

# %%
reviews.head(1)
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
#
#          designation  points  price    province     region_1 region_2  \
# 0  Martha's Vineyard      96  235.0  California  Napa Valley     Napa
#
#               variety winery
# 0  Cabernet Sauvignon  Heitz

# %%
reviews.country + " - " + reviews.region_1
# Out:
# 0                  US - Napa Valley
# 1                      Spain - Toro
# 2               US - Knights Valley
# 3            US - Willamette Valley
# 4                   France - Bandol
#                     ...
# 150925    Italy - Fiano di Avellino
# 150926           France - Champagne
# 150927    Italy - Fiano di Avellino
# 150928           France - Champagne
# 150929           Italy - Alto Adige
# Length: 150930, dtype: object

# %% [markdown]
# #### Questions:

# %% [markdown]
# 1. What is the median of the points column in the reviews DataFrame?

# %%
median_points = reviews.points.median()
median_points
# Out:
# np.float64(88.0)

# %% [markdown]
# 2. What countries are represented in the dataset? (Your answer should not include any duplicates.)

# %%
countries = reviews.country.unique()
countries
# Out:
# array(['US', 'Spain', 'France', 'Italy', 'New Zealand', 'Bulgaria',
#        'Argentina', 'Australia', 'Portugal', 'Israel', 'South Africa',
#        'Greece', 'Chile', 'Morocco', 'Romania', 'Germany', 'Canada',
#        'Moldova', 'Hungary', 'Austria', 'Croatia', 'Slovenia', nan,
#        'India', 'Turkey', 'Macedonia', 'Lebanon', 'Serbia', 'Uruguay',
#        'Switzerland', 'Albania', 'Bosnia and Herzegovina', 'Brazil',
#        'Cyprus', 'Lithuania', 'Japan', 'China', 'South Korea', 'Ukraine',
#        'England', 'Mexico', 'Georgia', 'Montenegro', 'Luxembourg',
#        'Slovakia', 'Czech Republic', 'Egypt', 'Tunisia', 'US-France'],
#       dtype=object)

# %% [markdown]
# 3. How often does each country appear in the dataset? Create a Series reviews_per_country mapping countries to the count of reviews of wines from that country.

# %%
reviews_per_country = reviews.country.value_counts()
reviews_per_country
# Out:
# country
# US                        62397
# Italy                     23478
# France                    21098
# Spain                      8268
# Chile                      5816
# Argentina                  5631
# Portugal                   5322
# Australia                  4957
# New Zealand                3320
# Austria                    3057
# Germany                    2452
# South Africa               2258
# Greece                      884
# Israel                      630
# Hungary                     231
# Canada                      196
# Romania                     139
# Slovenia                     94
# Uruguay                      92
# Croatia                      89
# Bulgaria                     77
# Moldova                      71
# Mexico                       63
# Turkey                       52
# Georgia                      43
# Lebanon                      37
# Cyprus                       31
# Brazil                       25
# Macedonia                    16
# ...
