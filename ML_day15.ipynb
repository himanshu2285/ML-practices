# %% [markdown]
# <a href="https://colab.research.google.com/github/himanshu2285/ML-practices/blob/main/ML_day15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Gathering
# ### 1. Working with csv data

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/automobile.csv')
df
# Out:
#      symboling  normalized-losses         make aspiration num-of-doors  \
# 0            3                122  alfa-romero        std          two
# 1            3                122  alfa-romero        std          two
# 2            1                122  alfa-romero        std          two
# 3            2                164         audi        std         four
# 4            2                164         audi        std         four
# ..         ...                ...          ...        ...          ...
# 196         -1                 95        volvo        std         four
# 197         -1                 95        volvo      turbo         four
# 198         -1                 95        volvo        std         four
# 199         -1                 95        volvo      turbo         four
# 200         -1                 95        volvo      turbo         four
#
#       body-style drive-wheels engine-location  wheel-base    length  ...  \
# ...

# %% [markdown]
# ## Reading csv Data from url

# %%
import requests
from io import StringIO

url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url, headers=headers)
data = StringIO(req.text)

pd.read_csv(data)
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %% [markdown]
# 1. **names** parameter are helpful to assign column names

# %%
df = pd.read_csv("/content/house-price.tsv",sep='\t')
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %% [markdown]
# 2. index_col parameter is helpful to assign a row as index column

# %%
df = pd.read_csv("/content/automobile.csv",index_col="symboling")
df
# Out:
#            normalized-losses         make aspiration num-of-doors  \
# symboling
#  3                       122  alfa-romero        std          two
#  3                       122  alfa-romero        std          two
#  1                       122  alfa-romero        std          two
#  2                       164         audi        std         four
#  2                       164         audi        std         four
# ...                      ...          ...        ...          ...
# -1                        95        volvo        std         four
# -1                        95        volvo      turbo         four
# -1                        95        volvo        std         four
# -1                        95        volvo      turbo         four
# -1                        95        volvo      turbo         four
#
#             body-style drive-wheels engine-location  wheel-base    length  \
# symboling
#  3         convertible          rwd           front        88.6  0.811148
# ...

# %% [markdown]
# 3. **header parameter** is help when we want that our first or any row should be in header(Columns name).

# %% [markdown]
# pd.read_csv("filename.csv",header=1)

# %% [markdown]
# 4. use_columns:

# %% [markdown]
# pd.read_csv('aug_train.csv',usecols=['enrollee_id','gender','education_level' ])
